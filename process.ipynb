# %%
# !python resize.py inputs/ceva
# Out:
# Successfully resized image: inputs/ceva\4549_0.png
# Successfully resized image: inputs/ceva\4549_1.png
# Successfully resized image: inputs/ceva\4549_1027.png
# Successfully resized image: inputs/ceva\4549_1028.png
# Successfully resized image: inputs/ceva\4549_1059.png
# Successfully resized image: inputs/ceva\4549_1060.png
# Successfully resized image: inputs/ceva\4549_1091.png
# Successfully resized image: inputs/ceva\4549_1092.png
# Successfully resized image: inputs/ceva\4549_1111.png
# Successfully resized image: inputs/ceva\4549_1112.png
# Successfully resized image: inputs/ceva\4549_1148.png
# Successfully resized image: inputs/ceva\4549_1149.png
# Successfully resized image: inputs/ceva\4549_1180.png
# Successfully resized image: inputs/ceva\4549_1181.png
# Successfully resized image: inputs/ceva\4549_1212.png
# Successfully resized image: inputs/ceva\4549_1213.png
# Successfully resized image: inputs/ceva\4549_1244.png
# ...

# %%
# !python run.py --model models/18junv10.pt --source inputs/ceva_processed --output outputs/CEVA
# Out:
# 0: 1280x1280 11 fs, 24.9ms
# Speed: 12.7ms preprocess, 24.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 11 fs, 24.9ms
# Speed: 11.2ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 9 fs, 7 rs, 24.9ms
# Speed: 11.7ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 8 fs, 6 rs, 24.4ms
# Speed: 12.7ms preprocess, 24.4ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 9 fs, 7 rs, 24.1ms
# Speed: 12.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 8 fs, 6 rs, 24.9ms
# Speed: 10.7ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 10 fs, 7 rs, 24.4ms
# Speed: 11.2ms preprocess, 24.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 8 fs, 6 rs, 24.4ms
# ...

# %%
# !python run.py --model models/18junv10.pt --source dataset/valid/images --output outputs/valid
# Out:
# 0: 1280x1280 41 fs, 24.4ms
# Speed: 13.7ms preprocess, 24.4ms inference, 2.9ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 45 fs, 6 ts, 23.9ms
# Speed: 13.2ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 41 fs, 6 ts, 23.9ms
# Speed: 12.2ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 50 fs, 11 ts, 24.3ms
# Speed: 11.9ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 71 fs, 42 ts, 23.9ms
# Speed: 13.2ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
#
# 0: 1280x1280 27 fs, 1 r, 51 ts, 23.9ms
# Speed: 10.8ms preprocess, 23.9ms inference, 2.2ms postprocess per image at shape (1, 3, 1280, 1280)

# %%
# !python resize.py inputs/BDF
# Out:
# ^C

# %%
# !python run.py --model models/18junv10.pt --source inputs/DHL-Lotus_processed/inputs/DHL-Lotus_processed --output outputs/DHL-Lotus2 --show True
